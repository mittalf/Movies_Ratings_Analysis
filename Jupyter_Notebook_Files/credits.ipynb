# %%
import pandas as pd
import csv

# %%
filename= "credits.csv"

credits  = pd.read_csv(filename)

#print(df.to_string())

credits.head(8)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
# 5  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 6  [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 7  [{'cast_id': 2, 'character': 'Tom Sawyer', 'cr...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
# 5  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949
# 6  [{'credit_id': '52fe44959251416c75039da9', 'de...  11860
# ...

# %%
all_casts = []
all_crews = []
for i in range(credits.shape[0]):
    cast = eval(credits['cast'][i])
    for x in cast:
        x['movie_id'] = credits['id'][i]
    crew = eval(credits['crew'][i])
    for x in crew:
        x['movie_id'] = credits['id'][i]
    all_casts.extend(cast)
    all_crews.extend(crew)

all_casts = pd.DataFrame(all_casts)
all_crews = pd.DataFrame(all_crews)

# %%
all_casts.head(20)
# Out:
#     cast_id                       character                 credit_id  gender  \
# 0        14                   Woody (voice)  52fe4284c3a36847f8024f95       2
# 1        15          Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2        16         Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3        17              Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4        18                     Rex (voice)  52fe4284c3a36847f8024fa5       2
# 5        19                    Hamm (voice)  52fe4284c3a36847f8024fa9       2
# 6        20                 Bo Peep (voice)  52fe4284c3a36847f8024fad       1
# 7        26                    Andy (voice)  52fe4284c3a36847f8024fc1       0
# 8        22                     Sid (voice)  52fe4284c3a36847f8024fb1       2
# 9        23              Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 10       24                Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# ...

# %%
cast = all_casts[['id','name','order', 'gender', 'movie_id']]
cast.head(30)
# Out:
#          id                name  order  gender  movie_id
# 0        31           Tom Hanks      0       2       862
# 1     12898           Tim Allen      1       2       862
# 2      7167         Don Rickles      2       2       862
# 3     12899          Jim Varney      3       2       862
# 4     12900       Wallace Shawn      4       2       862
# 5      7907   John Ratzenberger      5       2       862
# 6      8873         Annie Potts      6       1       862
# 7   1116442         John Morris      7       0       862
# 8     12901     Erik von Detten      8       2       862
# 9     12133      Laurie Metcalf      9       1       862
# 10     8655        R. Lee Ermey     10       2       862
# 11    12903       Sarah Freeman     11       1       862
# 12    37221       Penn Jillette     12       2       862
# 13     2157      Robin Williams      0       2      8844
# 14     8537       Jonathan Hyde      1       2      8844
# ...

# %%
crew = all_crews[['name', 'job', 'gender', 'movie_id']]
crew.tail(10)
# Out:
#                        name                      job  gender  movie_id
# 464304             Lav Diaz                   Editor       0    111109
# 464305             Lav Diaz           Cinematography       0    111109
# 464306       Mark L. Lester                 Director       2     67758
# 464307   C. Courtney Joyner               Screenplay       2     67758
# 464308   Jeffrey Goldenberg               Screenplay       2     67758
# 464309       Richard McHugh  Original Music Composer       0     67758
# 464310       João Fernandes  Director of Photography       2     67758
# 464311     Yakov Protazanov                 Director       0    227506
# 464312  Joseph N. Ermolieff                 Producer       2    227506
# 464313        Daisy Asquith                 Director       0    461257

# %%
movieid_count = crew["movie_id"].count

# %%
print(movieid_count)
# Out:
# <bound method Series.count of 0            862
# 1            862
# 2            862
# 3            862
# 4            862
#            ...
# 464309     67758
# 464310     67758
# 464311    227506
# 464312    227506
# 464313    461257
# Name: movie_id, Length: 464314, dtype: int64>

# %%
crew.to_csv('crew.csv')

# %%
cast.to_csv('cast.csv')
